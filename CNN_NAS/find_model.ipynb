# %%
import torch
model = torch.load(r"..\Models\nas_cnn_ransomware_model\best_nas_model.pth")
model
# Out:
# OrderedDict([('conv_layers.0.weight',
#               tensor([[[ 0.1219,  0.0440, -0.0425],
#                        [ 0.0023,  0.0524, -0.0023],
#                        [-0.0635, -0.0077,  0.0649],
#                        ...,
#                        [-0.0801, -0.0863, -0.1223],
#                        [-0.0357,  0.0302, -0.1571],
#                        [ 0.0375, -0.0883, -0.0410]],
#
#                       [[ 0.0076,  0.0129,  0.0298],
#                        [-0.1075,  0.0449, -0.0995],
#                        [-0.0765,  0.0323, -0.0499],
#                        ...,
#                        [ 0.0509, -0.0008,  0.1994],
#                        [-0.0263,  0.0768,  0.0231],
#                        [ 0.0362,  0.0948,  0.0462]],
#
#                       [[ 0.0046,  0.0353, -0.1172],
#                        [-0.0919,  0.0383,  0.0986],
#                        [ 0.0360, -0.0624, -0.1013],
#                        ...,
#                        [-0.0459, -0.1509, -0.2381],
# ...

# %%
from torchinfo import summary

# Display the model architecture
model = torch.load(r"..\Models\nas_cnn_ransomware_model\best_nas_model.pth")
summary(model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Display the model architecture
#       4 model = torch.load(r"..\Models\nas_cnn_ransomware_model\best_nas_model.pth")
# ----> 5 summary(model)
#
# File c:\Users\Hashil Jugjivan\OneDrive - Nanyang Technological University\Desktop\FYP -Detecting Ransomware Using HPCs\.venv\Lib\site-packages\torchinfo\torchinfo.py:212, in summary(model, input_size, input_data, batch_dim, cache_forward_pass, col_names, col_width, depth, device, dtypes, mode, row_settings, verbose, **kwargs)
#     209     cache_forward_pass = False
#     211 if device is None:
# --> 212     device = get_device(model, input_data)
#     213 elif isinstance(device, str):
#     214     device = torch.device(device)
#
# ...
